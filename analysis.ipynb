# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
data.replace("FALSE", 0, inplace=True)

# %%
data
# Out:
#      Team Number  Match  AC1T  AC1  AC2T  AC2  AC3T  AC3  AC4T  AC4  ...  \
# 0           7038     59     0    0     0    0     0    0     0    0  ...
# 1           6318     59     0    0     0    0     0    0     0    0  ...
# 2           3197     60     0    0     0    0     0    0     1    0  ...
# 3           8122     60     2    0     0    0     0    0     0    0  ...
# 4           4511     60     0    0     0    0     0    0     0    0  ...
# ..           ...    ...   ...  ...   ...  ...   ...  ...   ...  ...  ...
# 453         1306     58     0    0     0    0     0    0     1    1  ...
# 454         3277     59     0    0     0    0     0    0     0    0  ...
# 455         2654     59     0    0     0    0     0    0     0    0  ...
# 456          876     59     0    0     0    0     0    0     2    1  ...
# 457         4674     59     1    0     0    0     0    0     0    0  ...
#
#      Teleop Coral L2 Rate  Teleop Coral L3 Rate  Teleop Coral L4 Rate  \
# ...

# %%
def resolve_rate(value):
    if value == 'FALSE':
        return 0
    elif type(value) == str:
        return float(value.replace('%', '')) / 100
    else:
        return value

# %%
for col in data.columns:
    if "Rate" in col:
        data[col] = data[col].apply(resolve_rate)

# %%
data
# Out:
#      Team Number  Match  AC1T  AC1  AC2T  AC2  AC3T  AC3  AC4T  AC4  ...  \
# 0           7038     59     0    0     0    0     0    0     0    0  ...
# 1           6318     59     0    0     0    0     0    0     0    0  ...
# 2           3197     60     0    0     0    0     0    0     1    0  ...
# 3           8122     60     2    0     0    0     0    0     0    0  ...
# 4           4511     60     0    0     0    0     0    0     0    0  ...
# ..           ...    ...   ...  ...   ...  ...   ...  ...   ...  ...  ...
# 453         1306     58     0    0     0    0     0    0     1    1  ...
# 454         3277     59     0    0     0    0     0    0     0    0  ...
# 455         2654     59     0    0     0    0     0    0     0    0  ...
# 456          876     59     0    0     0    0     0    0     2    1  ...
# 457         4674     59     1    0     0    0     0    0     0    0  ...
#
#      Teleop Coral L2 Rate  Teleop Coral L3 Rate  Teleop Coral L4 Rate  \
# ...
